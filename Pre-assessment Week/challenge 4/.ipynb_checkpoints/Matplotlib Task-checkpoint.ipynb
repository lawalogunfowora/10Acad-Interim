# %% [markdown]
# # Matplolib Task

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %config InlineBackend.figure_format = 'retina'
plt.style.use("seaborn")

# %%
data = pd.read_csv("pandas_tasks.csv")

# %% [markdown]
# ## Instruction

# %% [markdown]
# * Using the loaded dataset, make a boxplot, barplot, histogram, and a scatter plot.
# * Ensure to provide appropriate labels, and titles where necessary.
# * In each plot, ensure to use all parameters used in the Matplolib tutorial.
# * Optionally, add additional parameters for each plot for some extra points.
# * For each of the plot, choose appropriate columns in the dataset. The explanation for each of the variables has been provided in a word document called `Variable_Codebook.docx`.

# %%
# Exploring the dataset
data.head(7)
# Out:
#      ID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2             ...               \
# 0  5086  98   2   3   1   1   2   2     0     0             ...
# 1  1258  40   1   1   3   5   1   1     1     0             ...
# 2   331  18   2   4   6   3   2   1     0     0             ...
# 3  6729  50   1   1   3   1   1   1     0     0             ...
# 4  8671  34   1   1   1   1   2   1     0     1             ...
# 5  5462  35   1   1   3   3   2   1     0     1             ...
# 6  4886  31   2   1   3   1   2   1     0     1             ...
#
#    Q17  Q18  Q19  Latitude  Longitude  mobile_money  savings  borrowing  \
# 0   -1    4    4 -4.460442  29.811396             0        0          0
# 1    4    1    4 -6.176438  39.244871             1        1          1
# 2   -1    1    1 -6.825702  37.652798             1        0          0
# 3   -1    1    4 -3.372049  35.808307             1        0          1
# 4   -1    1    4 -7.179645  31.039095             1        1          0
# ...

# %% [markdown]
# ## Boxplot
#
# Using the latitude column

# %%
plt.boxplot(data['Latitude'], widths=0.1, patch_artist=True, boxprops=dict(facecolor="red"))
plt.title('Boxplot of the Approximate latitude of the dataset')
plt.ylim(-15,0)
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# ## Bar Chart
#
# Using Q3, Q1, Q16 & Q17

# %%
plt.bar(data['Q3'], data['Q1'], color='green', width=0.4)
plt.ylim(0,110)
plt.title("A Bar plot of marital status and age")
plt.xlabel("Marital Status")
plt.ylabel("Ages")
positions = (1, 2, 3, 4)
labels = ("Married", "Divorced", "Widowed", "Single")
plt.xticks(positions, labels)
plt.show()

# %%
goods_services = data['Q16'][:10]
bills = data['Q17'][:10]
ind = np.arange(10) # creates a numpy array from 0 to 3. it will be used on the x-axis
width = 0.3 # will be used to specify the width of the bar
# plt.xticks(ind + width / 2, ('Not Applicable', 'Never', 'Daily', 'Weekly', 'Monthly', 'Less often than monthly'), rotation=50)
plt.bar(ind, goods_services, width, label="Goods/Services")
plt.bar(ind + width, bills, width, label="Bills")
plt.title("A Bar Plot comparing the the use of mobile for paying bills and purchasing goods/services")
plt.xlabel("Value")
plt.ylabel("Count")
plt.ylim(-2, 6)
plt.legend()
plt.show()

# %% [markdown]
# ## Histogram
# Using Ages

# %%
plt.hist(data['Q1'], bins=30, histtype='step', color='red')
plt.title("A Histogram showing the distribution of the ages in the dataset")
plt.xlabel("Ages")
plt.ylabel("Frequency")
plt.ylim(0, 900)
plt.xlim(10, 110)
plt.show;

# %% [markdown]
# ## Scatter Plot

# %%
plt.scatter(data['Latitude'], data['Longitude'], color='red')
plt.title("A scatter plot showing the relationship between Latitude and Longitude")
plt.xlabel("Latitude")
plt.ylabel("Longitude")
plt.ylim(28, 43)
plt.show()
